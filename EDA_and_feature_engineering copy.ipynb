# %%
from pandas import read_csv as rc
from pandas import DataFrame as df
from tqdm import tqdm
import numpy as np
import pandas as pd
from statsmodels.tsa.stattools import adfuller
from datetime import datetime
import matplotlib.pyplot as plt

# %%
df_dict = {}

for asset_id in range(1, 14):
    df_dict[f'Asset_{asset_id}'] = rc(f"/Users/ryanlucas/Desktop/G-Research/Data/Asset-{asset_id}.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-58-3898e999aaa9> in <module>
#       2
#       3 for asset_id in range(1, 14):
# ----> 4     df_dict[f'Asset_{asset_id}'] = rc(f"/Users/ryanlucas/Desktop/G-Research/Data/Asset-{asset_id}.csv")
#
# ...

# %%
features_dict = {}

for asset_id in range(1, 14):
    features_dict[f'Asset_{asset_id}'] = rc(f"/Users/ryanlucas/Desktop/G-Research/Data/Asset-{asset_id}_features.csv")

# %%
features_dict[f'Asset_6']
# Out:
#         Unnamed: 0  VWAP_Delta_5  VWAP_Delta_1  Upper Shadow  Lower Shadow
# 0                0     -0.005460      0.000772      7.492500      5.792500
# 1                1     -0.005460      0.000772      6.632500      5.770000
# 2                2     -0.005460      0.000372      6.787500      7.502500
# 3                3     -0.005460      0.000937      7.467500      8.172500
# 4                4     -0.005460      0.001548      7.270000      8.595000
# ...            ...           ...           ...           ...           ...
# 855542      855542      0.001715      0.000045      0.160000      0.138000
# 855543      855543      0.001601      0.000106      0.196000      0.106000
# 855544      855544      0.001125      0.000246      0.174000      0.086000
# 855545      855545      0.000952      0.000201      0.164000      0.206000
# 855546      855546      0.000722      0.000214      0.256667      0.186667
#
# [855547 rows x 5 columns]

# %%
df_dict[f'Asset_1'].describe().iloc[:, 1:].round(2).to_latex("/Users/ryanlucas/Desktop/feature_desc.txt")

# %%
df_dict[f'Asset_1']
# Out:
#                      A1_timestamp  A1_Count       A1_Open       A1_High  \
# Date
# 2018-01-01 00:01:00    1514764860       229  13835.194000  14013.800000
# 2018-01-01 00:02:00    1514764920       235  13835.036000  14052.300000
# 2018-01-01 00:03:00    1514764980       528  13823.900000  14000.400000
# 2018-01-01 00:04:00    1514765040       435  13802.512000  13999.000000
# 2018-01-01 00:05:00    1514765100       742  13766.000000  13955.900000
# ...                           ...       ...           ...           ...
# 2019-12-30 14:53:00    1577717580       295   7302.598468   7328.900000
# 2019-12-30 14:54:00    1577717640       524   7306.661622   7329.000000
# 2019-12-30 14:55:00    1577717700       335   7303.397104   7329.000000
# 2019-12-30 14:56:00    1577717760       744   7307.206667   7329.000000
# 2019-12-30 14:57:00    1577717820       418   7299.977104   7328.999731
#
#                        A1_Low      A1_Close   A1_Volume       A1_VWAP  \
# Date
# ...

# %%
features_dict['Asset_1']
# Out:
#          Unnamed: 0  VWAP_Delta_5  VWAP_Delta_1  Upper Shadow  Lower Shadow
# 0                 0     -0.008725      0.000961    163.624000    169.084000
# 1                 1     -0.008725      0.000961    217.264000    148.102000
# 2                 2     -0.008725      0.002481    176.500000    200.314000
# 3                 3     -0.008725      0.001629    196.488000    191.760000
# 4                 4     -0.008725      0.003489    189.900000    170.474000
# ...             ...           ...           ...           ...           ...
# 1956277     1956277      0.000074      0.001123     18.070849     20.752857
# 1956278     1956278     -0.001954      0.001303     27.802857     19.845714
# 1956279     1956279     -0.002773      0.000828     28.114286     29.820000
# 1956280     1956280     -0.001061      0.002137     24.882857     20.912802
# 1956281     1956281      0.000643      0.001760     38.548750     40.865000
#
# [1956282 rows x 5 columns]

# %%
avg_ticks_per_min = []

for asset_id in tqdm(range(1, 14), position = 0, leave = True):
    real_dates = [datetime.utcfromtimestamp(value).strftime('%Y-%m-%d %H:%M:%S') for value in df_dict[f'Asset_{asset_id}'][f'timestamp']]
    minutes_elapsed = [abs(pd.to_datetime(value[:10] +  " 00:00:00") - pd.to_datetime(value)).total_seconds()/60 for value in real_dates ]
    features_dict[f'Asset_{asset_id}']['minutes_elapsed'] = minutes_elapsed
# Out:
#  38%|███▊      | 5/13 [42:41<1:08:17, 512.25s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-f5d7ce741b71> in <module>
#       4     real_dates = [datetime.utcfromtimestamp(value).strftime('%Y-%m-%d %H:%M:%S') for value in df_dict[f'Asset_{asset_id}'][f'timestamp']]
#       5     minutes_elapsed = [abs(pd.to_datetime(value[:10] +  " 00:00:00") - pd.to_datetime(value)).total_seconds()/60 for value in real_dates ]
# ----> 6     features_dict[f'Asset_{asset_id}']['minutes_elapsed'] = minutes_elapsed
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ...

# %%
features_dict
# Out:
# {'Asset_1':          Unnamed: 0  VWAP_Delta_5  VWAP_Delta_1  Upper Shadow  Lower Shadow  \
#  0                 0     -0.008725      0.000961    163.624000    169.084000
#  1                 1     -0.008725      0.000961    217.264000    148.102000
#  2                 2     -0.008725      0.002481    176.500000    200.314000
#  3                 3     -0.008725      0.001629    196.488000    191.760000
#  4                 4     -0.008725      0.003489    189.900000    170.474000
#  ...             ...           ...           ...           ...           ...
#  1956277     1956277      0.000074      0.001123     18.070849     20.752857
#  1956278     1956278     -0.001954      0.001303     27.802857     19.845714
#  1956279     1956279     -0.002773      0.000828     28.114286     29.820000
#  1956280     1956280     -0.001061      0.002137     24.882857     20.912802
#  1956281     1956281      0.000643      0.001760     38.548750     40.865000
#
#           minutes_elapsed
# ...
